# %% [markdown]
# <h1 style="text-align: center;"><a title="Data Prep-AIMS-Cmr-2024-25">Assignment 1, Data Prep  @AIMSSen 25</h1>
#
# **Instructor:**
#
# * Rockefeller

# %% [markdown]
# **Prénom:Ahmed Souleymane**
#
# **Nom:Sow**

# %% [markdown]
# # Exercice 1:  Trends in Business in Nigeria

# %% [markdown]
# **NaijaBiz Analytics** is a leading business intelligence firm that specializes in analyzing small and medium enterprises (SMEs) across Nigeria. The company has been contracted by the Nigerian Ministry of Industry, Trade and Investment to conduct a comprehensive analysis of business performance across different states and sectors.
#
# As a newly hired Data Analyst at NaijaBiz Analytics, you have been provided with a dataset containing information about businesses across various Nigerian states. Your task is to analyze the business data using basic filtering operations to provide actionable insights.
#
# **Dataset:** `naija_businesses.csv`
#
# For each question below, provide the Python pandas code and extract meaningful business insights from your analysis.

# %%
import pandas as pd
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/usr/lib/python3/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/lib/python3/dist-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
# ...

# %%
df = pd.read_csv('data/naija_businesses.csv')
df
# Out:
#     business_id business_name   state  business_type  start_date  \
# 0       NG_0001    Business_1   Benue         Retail  2023-02-01
# 1       NG_0002    Business_2  Kaduna  Manufacturing  2023-11-17
# 2       NG_0003    Business_3     Oyo     Technology  2020-09-02
# 3       NG_0004    Business_4   Benue  Manufacturing  2023-04-14
# 4       NG_0005    Business_5  Rivers     Technology  2022-11-28
# ..          ...           ...     ...            ...         ...
# 195     NG_0196  Business_196    Kano       Services  2023-09-27
# 196     NG_0197  Business_197    Kano    Agriculture  2021-01-31
# 197     NG_0198  Business_198  Kaduna    Agriculture  2021-11-29
# 198     NG_0199  Business_199     Oyo    Agriculture  2022-11-08
# 199     NG_0200  Business_200  Rivers         Retail  2020-06-25
#
#      monthly_revenue_naira  monthly_costs_naira  employees  has_website  \
# 0                   417741               406718          8        False
# ...

# %%
df.head()
# Out:
#   business_id business_name   state  business_type  start_date  \
# 0     NG_0001    Business_1   Benue         Retail  2023-02-01
# 1     NG_0002    Business_2  Kaduna  Manufacturing  2023-11-17
# 2     NG_0003    Business_3     Oyo     Technology  2020-09-02
# 3     NG_0004    Business_4   Benue  Manufacturing  2023-04-14
# 4     NG_0005    Business_5  Rivers     Technology  2022-11-28
#
#    monthly_revenue_naira  monthly_costs_naira  employees  has_website  \
# 0                 417741               406718          8        False
# 1                 696804               256593         10         True
# 2                 520713                87719         11        False
# 3                 553527               389310          7        False
# 4                 231537               -11869         10         True
#
#    accepts_mobile_money
# 0                  True
# 1                 False
# 2                  True
# 3                  True
# 4                 False

# %%
df.tail()
# Out:
#     business_id business_name   state business_type  start_date  \
# 195     NG_0196  Business_196    Kano      Services  2023-09-27
# 196     NG_0197  Business_197    Kano   Agriculture  2021-01-31
# 197     NG_0198  Business_198  Kaduna   Agriculture  2021-11-29
# 198     NG_0199  Business_199     Oyo   Agriculture  2022-11-08
# 199     NG_0200  Business_200  Rivers        Retail  2020-06-25
#
#      monthly_revenue_naira  monthly_costs_naira  employees  has_website  \
# 195                 611128               415487          8         True
# 196                 916895               349547          7        False
# 197                 778180               430501          8        False
# 198                  98486                78788          4        False
# 199                 713491               339290         10        False
#
#      accepts_mobile_money
# 195                 False
# 196                  True
# 197                  True
# 198                  True
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   business_id            200 non-null    object
#  1   business_name          200 non-null    object
#  2   state                  200 non-null    object
#  3   business_type          200 non-null    object
#  4   start_date             200 non-null    object
#  5   monthly_revenue_naira  200 non-null    int64
#  6   monthly_costs_naira    200 non-null    int64
#  7   employees              200 non-null    int64
#  8   has_website            200 non-null    bool
#  9   accepts_mobile_money   200 non-null    bool
# dtypes: bool(2), int64(3), object(5)
# memory usage: 13.0+ KB

# %%
df.columns
# Out:
# Index(['business_id', 'business_name', 'state', 'business_type', 'start_date',
#        'monthly_revenue_naira', 'monthly_costs_naira', 'employees',
#        'has_website', 'accepts_mobile_money'],
#       dtype='object')

# %%
df.describe()
# Out:
#        monthly_revenue_naira  monthly_costs_naira   employees
# count             200.000000           200.000000  200.000000
# mean           493810.380000        255533.415000    7.800000
# std            210278.056439        138469.364304    2.989092
# min           -172819.000000       -138255.000000    1.000000
# 25%            351763.000000        163606.000000    6.000000
# 50%            508805.000000        260947.000000    8.000000
# 75%            652652.250000        349947.250000   10.000000
# max            934568.000000        572702.000000   16.000000

# %%
df.shape
# Out:
# (200, 10)

# %%
df.dtypes
# Out:
# business_id              object
# business_name            object
# state                    object
# business_type            object
# start_date               object
# monthly_revenue_naira     int64
# monthly_costs_naira       int64
# employees                 int64
# has_website                bool
# accepts_mobile_money       bool
# dtype: object

# %%
df['start_date'] = pd.to_datetime(df['start_date'])

# %%
df.dtypes
# Out:
# business_id                      object
# business_name                    object
# state                            object
# business_type                    object
# start_date               datetime64[ns]
# monthly_revenue_naira             int64
# monthly_costs_naira               int64
# employees                         int64
# has_website                        bool
# accepts_mobile_money               bool
# dtype: object

# %% [markdown]
# ### Q1: High Revenue Businesses
# Filter and display all businesses that have monthly revenue greater than 600,000 Naira. How many such businesses exist?
#
# **Business Context:** Identifying high-revenue businesses can help understand successful business models.

# %%
df[df['monthly_revenue_naira'] > 600000]
# Out:
#     business_id business_name    state  business_type start_date  \
# 1       NG_0002    Business_2   Kaduna  Manufacturing 2023-11-17
# 6       NG_0007    Business_7      Oyo       Services 2021-06-21
# 7       NG_0008    Business_8      Oyo     Technology 2022-07-09
# 11      NG_0012   Business_12    Benue       Services 2022-06-21
# 12      NG_0013   Business_13   Rivers  Manufacturing 2020-02-05
# 18      NG_0019   Business_19  Anambra  Manufacturing 2021-10-15
# 27      NG_0028   Business_28     Kano         Retail 2020-02-20
# 29      NG_0030   Business_30   Kaduna         Retail 2023-04-28
# 30      NG_0031   Business_31      Oyo       Services 2023-02-22
# 36      NG_0037   Business_37   Kaduna       Services 2021-11-12
# 38      NG_0039   Business_39    Lagos     Technology 2022-12-13
# 39      NG_0040   Business_40   Rivers         Retail 2022-09-29
# 40      NG_0041   Business_41   Rivers       Services 2021-03-19
# ...

# %%
df_revenue_great= df[df['monthly_revenue_naira'] > 600000]

# %%
count_ent_revenue_eleve = df_revenue_great["business_id"].count()
count_ent_revenue_eleve
# Out:
# np.int64(60)

# %%
pourcent_ent_revenue_great = (count_ent_revenue_eleve/df['business_id'].count())*100
pourcent_ent_revenue_great
# Out:
# np.float64(30.0)

# %% [markdown]
#  Alors on peut dire qu'il y'a `60 enteprises` qui ont un revenue superieur à `600,000 naira`.
#  Ces entreprises représentent donc `30.0% du total`.
#
# Les entreprises dont le revenu mensuel dépasse `600,000 Naira` représentent les acteurs les plus performants du marché. Leur position dominante traduit une gestion efficace, une offre à forte valeur ajoutée et une stratégie commerciale bien structurée. Elles constituent des modèles économiques de référence, susceptibles d’attirer des partenariats ou des investissements, et contribuent de manière notable à la croissance économique, à l’emploi et à la création de valeur dans leur secteur.

# %% [markdown]
# ### Q2: Technology Businesses with Websites
# Filter businesses that are in the "Technology" sector AND have a website. Display their business names and monthly revenue.
#
# **Business Context:** Understanding digital adoption in the tech sector can inform technology support programs.

# %%
df[(df['business_type'] == 'Technology') & (df['has_website'] == True)][['business_name', 'monthly_revenue_naira']]
# Out:
#     business_name  monthly_revenue_naira
# 4      Business_5                 231537
# 9     Business_10                 549862
# 33    Business_34                 265604
# 74    Business_75                 370740
# 115  Business_116                 742563
# 144  Business_145                 349510
# 161  Business_162                 319976
# 176  Business_177                 673369

# %% [markdown]
# On constate que ces entreprises sont à la fois numériquement actives et économiquement performantes, car leur présence en ligne favorise la visibilité, l’accès à de nouveaux marchés et la croissance du chiffre d’affaires.
#
# Ainsi, les entreprises technologiques disposant d’un site web démontrent une forte intégration du numérique et une orientation vers l’innovation. Leur digitalisation renforce leur compétitivité, améliore leur visibilité et soutient leur expansion, faisant d’elles des acteurs clés de la transformation numérique et des cibles prioritaires pour les programmes de soutien au secteur technologique.

# %% [markdown]
# ### Q3: Manufacturing Businesses in Specific States
# Filter all Manufacturing businesses located in either "Lagos" OR "Kano" states. How many manufacturing businesses are in these two states?
#
# **Business Context:** These states are major industrial hubs, and this analysis helps understand manufacturing concentration.

# %%
df_locat = df[(df['business_type']== 'Manufacturing') & (df['state'] == 'Lagos') | (df['state'] == 'Kano')][['business_id','business_name']] 
df_locat
# Out:
#     business_id business_name
# 9       NG_0010   Business_10
# 22      NG_0023   Business_23
# 27      NG_0028   Business_28
# 33      NG_0034   Business_34
# 42      NG_0043   Business_43
# 65      NG_0066   Business_66
# 70      NG_0071   Business_71
# 71      NG_0072   Business_72
# 73      NG_0074   Business_74
# 75      NG_0076   Business_76
# 87      NG_0088   Business_88
# 89      NG_0090   Business_90
# 92      NG_0093   Business_93
# 96      NG_0097   Business_97
# 101     NG_0102  Business_102
# 102     NG_0103  Business_103
# 104     NG_0105  Business_105
# 105     NG_0106  Business_106
# 122     NG_0123  Business_123
# 126     NG_0127  Business_127
# 127     NG_0128  Business_128
# 155     NG_0156  Business_156
# 157     NG_0158  Business_158
# 164     NG_0165  Business_165
# 165     NG_0166  Business_166
# 186     NG_0187  Business_187
# 195     NG_0196  Business_196
# 196     NG_0197  Business_197

# %%
df_locat.count()
# Out:
# business_id      28
# business_name    28
# dtype: int64

# %% [markdown]
# La concentration des entreprises manufacturières à Lagos et Kano illustre l’importance de ces États comme centres industriels stratégiques. Cette localisation favorise l’accès aux infrastructures, aux marchés et à la main-d’œuvre qualifiée, renforçant la compétitivité et l’efficacité de la production.
#
# Pour les investisseurs et décideurs, ces pôles représentent des zones prioritaires pour le développement industriel, les partenariats et les politiques de soutien, tandis que les entreprises en dehors de ces États pourraient envisager la relocalisation ou l’expansion pour bénéficier de ces avantages.

# %%
df[(df['employees'] >= 5) & (df['monthly_costs_naira'] < 200000)]
# Out:
#     business_id business_name    state  business_type start_date  \
# 2       NG_0003    Business_3      Oyo     Technology 2020-09-02
# 4       NG_0005    Business_5   Rivers     Technology 2022-11-28
# 5       NG_0006    Business_6  Anambra     Technology 2022-01-28
# 7       NG_0008    Business_8      Oyo     Technology 2022-07-09
# 20      NG_0021   Business_21      Imo  Manufacturing 2021-04-15
# 26      NG_0027   Business_27      Imo         Retail 2022-05-03
# 27      NG_0028   Business_28     Kano         Retail 2020-02-20
# 33      NG_0034   Business_34     Kano     Technology 2021-07-23
# 34      NG_0035   Business_35      Imo         Retail 2023-09-27
# 37      NG_0038   Business_38    Lagos         Retail 2022-04-17
# 39      NG_0040   Business_40   Rivers         Retail 2022-09-29
# 45      NG_0046   Business_46   Kaduna  Manufacturing 2022-09-30
# 53      NG_0054   Business_54   Kaduna         Retail 2023-10-05
# ...

# %%
df[(df['employees'] >= 5) & (df['monthly_costs_naira'] < 200000)]
# Out:
#     business_id business_name    state  business_type start_date  \
# 2       NG_0003    Business_3      Oyo     Technology 2020-09-02
# 4       NG_0005    Business_5   Rivers     Technology 2022-11-28
# 5       NG_0006    Business_6  Anambra     Technology 2022-01-28
# 7       NG_0008    Business_8      Oyo     Technology 2022-07-09
# 20      NG_0021   Business_21      Imo  Manufacturing 2021-04-15
# 26      NG_0027   Business_27      Imo         Retail 2022-05-03
# 27      NG_0028   Business_28     Kano         Retail 2020-02-20
# 33      NG_0034   Business_34     Kano     Technology 2021-07-23
# 34      NG_0035   Business_35      Imo         Retail 2023-09-27
# 37      NG_0038   Business_38    Lagos         Retail 2022-04-17
# 39      NG_0040   Business_40   Rivers         Retail 2022-09-29
# 45      NG_0046   Business_46   Kaduna  Manufacturing 2022-09-30
# 53      NG_0054   Business_54   Kaduna         Retail 2023-10-05
# ...

# %% [markdown]
# On peut dire que ces entreprises sont de petites structures, souvent des startups, micro-entreprises ou activités individuelles, opérant avec des ressources limitées.
#
# Ces petits acteurs représentent la base dynamique de l’économie locale, caractérisée par une capacité d’adaptation rapide aux besoins du marché. Leur taille réduite et leurs coûts modestes les rendent fragiles face aux fluctuations économiques, mais aussi réactifs et innovants.

# %% [markdown]
# ### Q5: Profitable Retail Businesses
# Filter Retail businesses where monthly revenue is greater than monthly costs. Display their state and employee count.
#
# **Business Context:** Understanding profitable retail operations can help identify successful business practices.

# %%
df[(df['business_type'] == 'Retail') & (df['monthly_revenue_naira'] > df['monthly_costs_naira'])][['state', 'employees']]
# Out:
#        state  employees
# 0      Benue          8
# 16    Kaduna          2
# 26       Imo         12
# 27      Kano         10
# 28   Anambra          3
# 29    Kaduna          6
# 31     Lagos          3
# 34       Imo          5
# 37     Lagos         10
# 39    Rivers          6
# 44    Kaduna          8
# 46   Anambra         11
# 47     Benue          2
# 53    Kaduna          5
# 55    Kaduna          8
# 56   Anambra          9
# 58    Rivers          7
# 63     Lagos          8
# 64     Benue         13
# 73      Kano         10
# 78     Benue          7
# 79    Kaduna         10
# 94       Imo          8
# 95       Imo          6
# 97    Kaduna          9
# 100    Benue          5
# 101     Kano         11
# 107   Kaduna          9
# 110  Anambra          9
# 117      Imo         10
# 118  Anambra          8
# 123    Benue          3
# 126     Kano         10
# 130   Kaduna         11
# 132    Lagos          8
# 139    Lagos         11
# 141    Lagos         10
# ...

# %% [markdown]
# ### Q6: Businesses Accepting Mobile Money
# Filter all businesses that accept mobile money AND have more than 8 employees. Which states are these businesses located in?
#
# **Business Context:** Larger businesses adopting mobile payments indicate financial technology integration.

# %%
df[(df['employees'] > 8) & (df['accepts_mobile_money'] == True)]
# Out:
#     business_id business_name    state  business_type start_date  \
# 2       NG_0003    Business_3      Oyo     Technology 2020-09-02
# 6       NG_0007    Business_7      Oyo       Services 2021-06-21
# 10      NG_0011   Business_11   Rivers       Services 2022-04-07
# 13      NG_0014   Business_14   Rivers    Agriculture 2021-11-15
# 21      NG_0022   Business_22      Oyo  Manufacturing 2023-03-12
# 26      NG_0027   Business_27      Imo         Retail 2022-05-03
# 35      NG_0036   Business_36      Oyo       Services 2020-10-31
# 36      NG_0037   Business_37   Kaduna       Services 2021-11-12
# 37      NG_0038   Business_38    Lagos         Retail 2022-04-17
# 41      NG_0042   Business_42    Benue    Agriculture 2021-09-04
# 45      NG_0046   Business_46   Kaduna  Manufacturing 2022-09-30
# 46      NG_0047   Business_47  Anambra         Retail 2020-01-05
# 56      NG_0057   Business_57  Anambra         Retail 2022-04-02
# ...

# %%
df[(df['employees'] > 8) & (df['accepts_mobile_money'] == True)]['state'].unique()
# Out:
# array(['Oyo', 'Rivers', 'Imo', 'Kaduna', 'Lagos', 'Benue', 'Anambra',
#        'Kano'], dtype=object)

# %% [markdown]
# Ces entreprises sont situées dans les Etats comme: `Oyo, Rivers, Imo, Kaduna, Lagos, Benue, Anambra et Kano`

# %% [markdown]
# ### Q7: Low-Cost Operations
# Filter businesses where monthly costs are less than 150,000 Naira. What is the most common business type among these low-cost operations?
#
# **Business Context:** Low-cost business models can be important for economic inclusion and job creation.

# %%
df[df['monthly_costs_naira'] < 150000]
# Out:
#     business_id business_name    state  business_type start_date  \
# 2       NG_0003    Business_3      Oyo     Technology 2020-09-02
# 4       NG_0005    Business_5   Rivers     Technology 2022-11-28
# 5       NG_0006    Business_6  Anambra     Technology 2022-01-28
# 7       NG_0008    Business_8      Oyo     Technology 2022-07-09
# 26      NG_0027   Business_27      Imo         Retail 2022-05-03
# 30      NG_0031   Business_31      Oyo       Services 2023-02-22
# 33      NG_0034   Business_34     Kano     Technology 2021-07-23
# 34      NG_0035   Business_35      Imo         Retail 2023-09-27
# 37      NG_0038   Business_38    Lagos         Retail 2022-04-17
# 39      NG_0040   Business_40   Rivers         Retail 2022-09-29
# 45      NG_0046   Business_46   Kaduna  Manufacturing 2022-09-30
# 57      NG_0058   Business_58    Lagos       Services 2022-07-24
# 65      NG_0066   Business_66     Kano       Services 2022-04-10
# ...

# %%
df[df['monthly_costs_naira'] < 150000]["business_type"].value_counts()
# Out:
# business_type
# Retail           12
# Services         11
# Technology        9
# Manufacturing     8
# Agriculture       7
# Name: count, dtype: int64

# %% [markdown]
# Ces structures à faible coût représentent des modèles économiques légers et accessibles, capables de créer de l’emploi tout en nécessitant peu de capital. Elles favorisent l’inclusion économique et constituent une base pour le développement local, mais leur petite taille les rend sensibles aux fluctuations du marché.

# %% [markdown]
# le type d’entreprise le plus fréquent parmi ces structures à faibles coûts est le service.

# %% [markdown]
# ### Q8: Recent Business Registrations
# Filter businesses that started in 2023. Which business type is most common among these new businesses?
#
# **Business Context:** Recent registration trends can indicate emerging business opportunities and economic growth sectors.

# %%
df[df['start_date'].dt.year == 2023][['business_id','business_name']]
# Out:
#     business_id business_name
# 0       NG_0001    Business_1
# 1       NG_0002    Business_2
# 3       NG_0004    Business_4
# 21      NG_0022   Business_22
# 22      NG_0023   Business_23
# 23      NG_0024   Business_24
# 29      NG_0030   Business_30
# 30      NG_0031   Business_31
# 34      NG_0035   Business_35
# 47      NG_0048   Business_48
# 48      NG_0049   Business_49
# 53      NG_0054   Business_54
# 62      NG_0063   Business_63
# 67      NG_0068   Business_68
# 71      NG_0072   Business_72
# 72      NG_0073   Business_73
# 78      NG_0079   Business_79
# 79      NG_0080   Business_80
# 82      NG_0083   Business_83
# 84      NG_0085   Business_85
# 85      NG_0086   Business_86
# 91      NG_0092   Business_92
# 93      NG_0094   Business_94
# 95      NG_0096   Business_96
# 97      NG_0098   Business_98
# 98      NG_0099   Business_99
# 106     NG_0107  Business_107
# 113     NG_0114  Business_114
# 114     NG_0115  Business_115
# 118     NG_0119  Business_119
# ...

# %%
df[df['start_date'].dt.year == 2023]['business_type'].value_counts()
# Out:
# business_type
# Retail           17
# Manufacturing    14
# Services          9
# Technology        7
# Agriculture       3
# Name: count, dtype: int64

# %% [markdown]
# Le type d’entreprise le plus courant parmi ces nouvelles créations est donc le commerce de détail.
#
# Les nouvelles entreprises créées en 2023 montrent une prépondérance du commerce de détail, suivi par le manufacturier et les services. Cela indique une dynamique de consommation locale forte et un intérêt croissant pour les secteurs à retour rapide et faible barrière à l’entrée. Ces tendances signalent les secteurs émergents et les opportunités économiques pour les investisseurs, les incubateurs et les décideurs souhaitant soutenir l’innovation et la création d’emplois.

# %% [markdown]
# ### Q9: Large Employers
# Filter businesses that have 10 or more employees. Calculate the average monthly revenue of these larger employers.
#
# **Business Context:** Large employers are important for job creation and economic stability.

# %%
df[df['employees'] >= 10]
# Out:
#     business_id business_name   state  business_type start_date  \
# 1       NG_0002    Business_2  Kaduna  Manufacturing 2023-11-17
# 2       NG_0003    Business_3     Oyo     Technology 2020-09-02
# 4       NG_0005    Business_5  Rivers     Technology 2022-11-28
# 6       NG_0007    Business_7     Oyo       Services 2021-06-21
# 7       NG_0008    Business_8     Oyo     Technology 2022-07-09
# ..          ...           ...     ...            ...        ...
# 186     NG_0187  Business_187    Kano         Retail 2023-10-24
# 191     NG_0192  Business_192  Rivers    Agriculture 2023-07-20
# 192     NG_0193  Business_193   Lagos       Services 2020-03-02
# 194     NG_0195  Business_195   Benue    Agriculture 2021-12-29
# 199     NG_0200  Business_200  Rivers         Retail 2020-06-25
#
#      monthly_revenue_naira  monthly_costs_naira  employees  has_website  \
# 1                   696804               256593         10         True
# ...

# %%
df[df['employees'] >= 10]['monthly_revenue_naira'].mean()
# Out:
# np.float64(511441.8548387097)

# %% [markdown]
# Les entreprises avec 10 employés ou plus génèrent généralement un revenu mensuel élevé, ce qui reflète leur capacité à produire, vendre et croître à plus grande échelle. Elles jouent un rôle clé dans la création d’emplois, la stabilité économique et le développement des secteurs industriels.

# %% [markdown]
# ### Q10: Digital-Ready Businesses
# Filter businesses that have a website AND accept mobile money. What percentage of the total businesses are digitally ready?
#
# **Business Context:** Digital readiness indicates how prepared businesses are for the modern economy.

# %%
df[(df['has_website'] == True) & (df['accepts_mobile_money'] == True)]
# Out:
#     business_id business_name    state  business_type start_date  \
# 14      NG_0015   Business_15  Anambra    Agriculture 2020-01-20
# 21      NG_0022   Business_22      Oyo  Manufacturing 2023-03-12
# 28      NG_0029   Business_29  Anambra         Retail 2021-07-28
# 33      NG_0034   Business_34     Kano     Technology 2021-07-23
# 34      NG_0035   Business_35      Imo         Retail 2023-09-27
# 37      NG_0038   Business_38    Lagos         Retail 2022-04-17
# 40      NG_0041   Business_41   Rivers       Services 2021-03-19
# 45      NG_0046   Business_46   Kaduna  Manufacturing 2022-09-30
# 56      NG_0057   Business_57  Anambra         Retail 2022-04-02
# 57      NG_0058   Business_58    Lagos       Services 2022-07-24
# 58      NG_0059   Business_59   Rivers         Retail 2021-10-17
# 64      NG_0065   Business_65    Benue         Retail 2020-04-29
# 68      NG_0069   Business_69   Kaduna  Manufacturing 2022-01-10
# ...

# %%
count_ent_num = df[(df['has_website'] == True) & (df['accepts_mobile_money'] == True)]['business_id'].count()

# %%
count_ent_num
# Out:
# np.int64(28)

# %%
percent = (count_ent_num/df['business_id'].count())*100

# %%
percent
# Out:
# np.float64(14.000000000000002)

# %% [markdown]
# Parmi toutes les entreprises analysées, `28 entreprises` disposent à la fois d’un site web et acceptent le mobile money, ce qui représente `14 % du total`.
# Ces entreprises peuvent donc être considérées comme numériquement prêtes.
#
# Le fait que seulement `14 % des entreprises` soient numériquement prêtes indique que la transformation digitale reste limitée. Les entreprises équipées de solutions numériques et de paiement mobile bénéficient d’un avantage concurrentiel : meilleure visibilité, accès élargi aux clients et efficacité opérationnelle.
# Pour stimuler la compétitivité et l’inclusion économique, il serait pertinent de promouvoir l’adoption numérique via des programmes de formation, des incitations financières et un accompagnement technologique, ciblant les `86 % restantes` qui ne sont pas encore digitalisées.

# %% [markdown]
# # Exercise 2: African Agriculture Analysis
#
# **AgriTech Africa** is a research organization analyzing agricultural technology adoption across five African countries. You have been provided with a dataset containing information about farming communities and their technology usage patterns.
#
# For each question below, provide the Python pandas code and provide a key insight you can get from your answer.

# %%
data = pd.read_csv('data/african_agriculture_dataset.csv')

# %%
data
# Out:
#                         Community_Name       Country Crop_Type  Farm_Size  \
# 0            Mountain Cultivators Club  South Africa    Barley      39.96
# 1             Prairie Cultivators Club  South Africa   Sorghum      77.62
# 2                 Prairie Agri Society       Nigeria     Wheat      97.46
# 3                Harvest Farmers Union       Nigeria     Maize      27.84
# 4                 Valley Farmers Group         Ghana   Sorghum      70.60
# ...                                ...           ...       ...        ...
# 1995              Harvest Agri Society         Kenya     Maize      39.93
# 1996            Mountain Farmers Group       Nigeria     Maize      50.99
# 1997          Prairie Cultivators Club         Ghana      Rice      89.37
# 1998  Sunrise Agricultural Association         Kenya     Wheat      87.01
# 1999            Savannah Farmers Group       Nigeria   Sorghum      57.86
#
#       Tech_Adoption_Index Drone_Usage  Mobile_Tech  Annual_Yield  \
# ...

# %%
data.head()
# Out:
#               Community_Name       Country Crop_Type  Farm_Size  \
# 0  Mountain Cultivators Club  South Africa    Barley      39.96
# 1   Prairie Cultivators Club  South Africa   Sorghum      77.62
# 2       Prairie Agri Society       Nigeria     Wheat      97.46
# 3      Harvest Farmers Union       Nigeria     Maize      27.84
# 4       Valley Farmers Group         Ghana   Sorghum      70.60
#
#    Tech_Adoption_Index Drone_Usage  Mobile_Tech  Annual_Yield Fertilizer_Type  \
# 0                   40         Yes          SMS        318.05         Organic
# 1                   48          No          SMS        704.85         Organic
# 2                   14         Yes          SMS        439.41             NaN
# 3                   55          No          SMS        668.23             NaN
# 4                   53         Yes  Mobile Apps        801.16             NaN
#
#   Irrigation Weather_Station  Annual_Rainfall
# 0  Sprinkler             Yes          1046.21
# ...

# %%
data.tail()
# Out:
#                         Community_Name  Country Crop_Type  Farm_Size  \
# 1995              Harvest Agri Society    Kenya     Maize      39.93
# 1996            Mountain Farmers Group  Nigeria     Maize      50.99
# 1997          Prairie Cultivators Club    Ghana      Rice      89.37
# 1998  Sunrise Agricultural Association    Kenya     Wheat      87.01
# 1999            Savannah Farmers Group  Nigeria   Sorghum      57.86
#
#       Tech_Adoption_Index Drone_Usage  Mobile_Tech  Annual_Yield  \
# 1995                    0         Yes          NaN        246.61
# 1996                   90          No          NaN        205.38
# 1997                   43          No  Mobile Apps        603.02
# 1998                   99          No  Mobile Apps        370.42
# 1999                   48          No  Mobile Apps        997.68
#
#      Fertilizer_Type Irrigation Weather_Station  Annual_Rainfall
# 1995             NaN        NaN             Yes          1123.58
# ...

# %%
data.shape
# Out:
# (2000, 12)

# %%
data.columns
# Out:
# Index(['Community_Name', 'Country', 'Crop_Type', 'Farm_Size',
#        'Tech_Adoption_Index', 'Drone_Usage', 'Mobile_Tech', 'Annual_Yield',
#        'Fertilizer_Type', 'Irrigation', 'Weather_Station', 'Annual_Rainfall'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Community_Name       2000 non-null   object
#  1   Country              2000 non-null   object
#  2   Crop_Type            2000 non-null   object
#  3   Farm_Size            2000 non-null   float64
#  4   Tech_Adoption_Index  2000 non-null   int64
#  5   Drone_Usage          2000 non-null   object
#  6   Mobile_Tech          1288 non-null   object
#  7   Annual_Yield         2000 non-null   float64
#  8   Fertilizer_Type      1307 non-null   object
#  9   Irrigation           1349 non-null   object
#  10  Weather_Station      2000 non-null   object
#  11  Annual_Rainfall      2000 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 187.6+ KB

# %%
data.describe()
# Out:
#          Farm_Size  Tech_Adoption_Index  Annual_Yield  Annual_Rainfall
# count  2000.000000          2000.000000   2000.000000      2000.000000
# mean     52.126350            50.044500    536.689350       794.925925
# std      28.786657            28.947133    257.207925       228.165699
# min       1.000000             0.000000    100.110000       400.000000
# 25%      27.330000            25.000000    311.357500       596.695000
# 50%      53.675000            50.000000    536.050000       798.695000
# 75%      76.907500            75.000000    752.900000       983.485000
# max      99.970000           100.000000    999.730000      1199.830000

# %%
data['Drone_Usage'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data['Mobile_Tech'].unique()
# Out:
# array(['SMS', 'Mobile Apps', nan], dtype=object)

# %%
data['Tech_Adoption_Index']
# Out:
# 0       40
# 1       48
# 2       14
# 3       55
# 4       53
#         ..
# 1995     0
# 1996    90
# 1997    43
# 1998    99
# 1999    48
# Name: Tech_Adoption_Index, Length: 2000, dtype: int64

# %%
data['Tech_Adoption_Index'].isna().sum()
# Out:
# np.int64(0)

# %%
data[['Tech_Adoption_Index', 'Drone_Usage', 'Mobile_Tech']].head(30)
# Out:
#     Tech_Adoption_Index Drone_Usage  Mobile_Tech
# 0                    40         Yes          SMS
# 1                    48          No          SMS
# 2                    14         Yes          SMS
# 3                    55          No          SMS
# 4                    53         Yes  Mobile Apps
# 5                    30         Yes          SMS
# 6                    60          No          NaN
# 7                    57          No          NaN
# 8                    86         Yes          SMS
# 9                    59         Yes          NaN
# 10                   52         Yes          NaN
# 11                   85         Yes          SMS
# 12                   60          No  Mobile Apps
# 13                   79         Yes  Mobile Apps
# 14                   41         Yes  Mobile Apps
# 15                   28          No          SMS
# 16                   83          No  Mobile Apps
# 17                   91          No  Mobile Apps
# ...

# %%
data[['Tech_Adoption_Index', 'Drone_Usage', 'Mobile_Tech']].sample(3)
# Out:
#       Tech_Adoption_Index Drone_Usage  Mobile_Tech
# 1296                   63         Yes          NaN
# 674                     2         Yes          SMS
# 1578                   44         Yes  Mobile Apps

# %%
data['Fertilizer_Type'].unique()
# Out:
# array(['Organic', nan, 'Inorganic'], dtype=object)

# %% [markdown]
# ## Q1: Identifying Technology Leaders
# **Business Question:** Which farming communities are leading in technology adoption, and how many of our partner communities have achieved a Technology Adoption Index above 80?
#
# **Context:** Understanding technology leaders helps identify best practices for scaling across other communities.

# %%
data.sort_values(['Community_Name', 'Tech_Adoption_Index'], ascending = False)
# Out:
#                 Community_Name       Country Crop_Type  Farm_Size  \
# 986   Valley Growers Coalition       Nigeria      Rice      42.28
# 910   Valley Growers Coalition  South Africa     Maize      29.12
# 1331  Valley Growers Coalition         Ghana     Maize      43.64
# 217   Valley Growers Coalition  South Africa    Barley      29.73
# 1484  Valley Growers Coalition  South Africa      Rice      85.88
# ...                        ...           ...       ...        ...
# 368        Golden Agri Society         Ghana   Sorghum      60.44
# 1684       Golden Agri Society         Ghana    Barley      78.32
# 1876       Golden Agri Society         Ghana    Barley      28.42
# 1197       Golden Agri Society         Ghana     Maize      65.96
# 1372       Golden Agri Society  South Africa   Sorghum      23.14
#
#       Tech_Adoption_Index Drone_Usage  Mobile_Tech  Annual_Yield  \
# 986                    99          No          NaN        215.56
# ...

# %%
community_parter = data.loc[data['Tech_Adoption_Index'] > 80, 'Community_Name']
community_parter.value_counts()
# Out:
# Community_Name
# Harvest Farmers Union                14
# Meadow Growers Coalition             12
# Meadow Farmers Union                 11
# Sunrise Agricultural Association     11
# Harvest Growers Coalition            10
# Meadow Farmers Group                 10
# Savannah Farmers Union               10
# River Agri Society                    9
# Valley Agri Society                   9
# Valley Farmers Union                  8
# Meadow Agri Society                   8
# Valley Growers Coalition              8
# Golden Growers Coalition              8
# Green Growers Coalition               8
# Mountain Farmers Group                8
# Golden Farmers Union                  8
# Harvest Agricultural Association      8
# Mountain Agri Society                 8
# Golden Cultivators Club               8
# Savannah Agri Society                 8
# Sunrise Growers Coalition             7
# Mountain Farmers Union                7
# Prairie Cultivators Club              7
# ...

# %%
community_parter.value_counts().count()
# Out:
# np.int64(60)

# %% [markdown]
# On constate que `60 nos communautés partenaires` ont `un indice d’adoption technologique supérieur à 80`
#
# Ainsi, ils jouent un rôle moteur dans la transformation agricole. Leur adoption précoce des innovations montre que ces technologies peuvent améliorer la productivité, la rentabilité et la résilience face aux aléas climatiques.

# %% [markdown]
# ## Q2: Premium Drone Adoption Analysis
# **Business Question:** Among large-scale farming operations (over 70 acres), which communities have invested in drone technology, and where are they located?
#
# **Context:** Large farms with drone adoption represent high-value clients for advanced agricultural technology partnerships.

# %%
data[(data['Farm_Size'] >= 70) & (data['Drone_Usage'] == 'Yes')][['Community_Name','Country']]
# Out:
#                  Community_Name       Country
# 2          Prairie Agri Society       Nigeria
# 4          Valley Farmers Group         Ghana
# 5         Savannah Agri Society      Tanzania
# 11    Sunrise Growers Coalition  South Africa
# 24         Meadow Farmers Group         Ghana
# ...                         ...           ...
# 1968  Harvest Growers Coalition      Tanzania
# 1974   Meadow Growers Coalition         Kenya
# 1988  Savannah Cultivators Club         Ghana
# 1991       Meadow Farmers Group         Kenya
# 1993        Golden Agri Society         Kenya
#
# [338 rows x 2 columns]

# %%
data[(data['Farm_Size'] >= 70) & (data['Drone_Usage'] == 'Yes')]['Country'].value_counts()
# Out:
# Country
# Ghana           78
# Tanzania        76
# Nigeria         67
# Kenya           60
# South Africa    57
# Name: count, dtype: int64

# %% [markdown]
# Les données montrent que plusieurs grandes exploitations agricoles utilisant des drones sont réparties dans cinq pays, avec une forte concentration au Ghana, en Tanzanie et au Nigéria.
#
# Ces pays représentent des marchés stratégiques pour le développement de partenariats en technologies agricoles avancées. Les groupes comme `Meadow Farmers Group, Savannah Agri Society ou Harvest Growers Coalition` apparaissent comme des leaders technologiques régionaux, susceptibles de devenir des ambassadeurs pour la diffusion des innovations agricoles (drones).

# %% [markdown]
# ## Q3: Market Expansion Opportunities
# **Business Question:** How many farming communities are operating in our priority markets of South Africa and Kenya?
#
# **Context:** These countries represent key expansion opportunities for agricultural technology solutions.

# %%
com_SA_KA = data.loc[((data['Country'] == 'South Africa') | (data['Country'] == 'Kenya')), 'Community_Name']
com_SA_KA
# Out:
# 0              Mountain Cultivators Club
# 1               Prairie Cultivators Club
# 6                River Growers Coalition
# 9              Sunrise Growers Coalition
# 11             Sunrise Growers Coalition
#                       ...
# 1989                Harvest Agri Society
# 1991                Meadow Farmers Group
# 1993                 Golden Agri Society
# 1995                Harvest Agri Society
# 1998    Sunrise Agricultural Association
# Name: Community_Name, Length: 760, dtype: object

# %%
com_SA_KA.value_counts().count()
# Out:
# np.int64(60)

# %%
data.loc[(data['Country'] == 'South Africa') | (data['Country'] == 'Kenya'), ['Country','Tech_Adoption_Index', 'Drone_Usage','Mobile_Tech']].head(20)
# Out:
#          Country  Tech_Adoption_Index Drone_Usage  Mobile_Tech
# 0   South Africa                   40         Yes          SMS
# 1   South Africa                   48          No          SMS
# 6   South Africa                   60          No          NaN
# 9          Kenya                   59         Yes          NaN
# 11  South Africa                   85         Yes          SMS
# 13  South Africa                   79         Yes  Mobile Apps
# 17  South Africa                   91          No  Mobile Apps
# 19         Kenya                   43          No  Mobile Apps
# 20         Kenya                   92          No          SMS
# 25         Kenya                   37          No          NaN
# 35         Kenya                   71         Yes  Mobile Apps
# 36  South Africa                   91          No  Mobile Apps
# 37         Kenya                   78          No          NaN
# 47         Kenya                   81          No          SMS
# ...

# %% [markdown]
# Nous avons 60 communautés agricoles qui opèrent dans les marchés prioritaires de l’Afrique du Sud et du Kenya.
# Ce nombre élevé confirme que ces deux pays disposent d’un écosystème agricole dynamique et technologiquement réceptif. La concentration de communautés agricoles actives crée une opportunité stratégique majeure pour déployer et tester des solutions AgriTech à grande échelle.

# %% [markdown]
# ## Q4: Underserved Market Identification
# **Business Question:** Which countries have small-scale, low-technology farming operations (under 20 acres with Technology Adoption Index below 30) that could benefit from basic technology interventions?
#
# **Context:** Small, low-tech farms represent an underserved market segment requiring tailored entry-level solutions.

# %%
data.loc[(data['Farm_Size'] < 20) & (data['Tech_Adoption_Index'] < 30), 'Country'].unique()
# Out:
# array(['Nigeria', 'South Africa', 'Kenya', 'Tanzania', 'Ghana'],
#       dtype=object)

# %% [markdown]
# Les résultats indiquent que le Nigeria, l’Afrique du Sud, le Kenya, la Tanzanie et le Ghana comptent des exploitations de petite taille (moins de 20 acres) avec un indice technologique inférieur à 30.
#
# Ces petites exploitations représentent un segment sous-technologisé mais à fort potentiel pour l’introduction de solutions agricoles de base, comme les outils de gestion simples, les applications mobiles pour agriculteurs ou des systèmes d’irrigation à faible coût.

# %% [markdown]
# ## Q5: Sustainable Agriculture Success Stories
# **Business Question:** Which organic farming communities are achieving high productivity (over 600 annual yield), and what irrigation technologies are they using?
#
# **Context:** Successful organic farms demonstrate sustainable practices that can be promoted to environmentally conscious markets.

# %%
data.head()
# Out:
#               Community_Name       Country Crop_Type  Farm_Size  \
# 0  Mountain Cultivators Club  South Africa    Barley      39.96
# 1   Prairie Cultivators Club  South Africa   Sorghum      77.62
# 2       Prairie Agri Society       Nigeria     Wheat      97.46
# 3      Harvest Farmers Union       Nigeria     Maize      27.84
# 4       Valley Farmers Group         Ghana   Sorghum      70.60
#
#    Tech_Adoption_Index Drone_Usage  Mobile_Tech  Annual_Yield Fertilizer_Type  \
# 0                   40         Yes          SMS        318.05         Organic
# 1                   48          No          SMS        704.85         Organic
# 2                   14         Yes          SMS        439.41             NaN
# 3                   55          No          SMS        668.23             NaN
# 4                   53         Yes  Mobile Apps        801.16             NaN
#
#   Irrigation Weather_Station  Annual_Rainfall
# 0  Sprinkler             Yes          1046.21
# ...

# %%
data.loc[(data['Fertilizer_Type'] == 'Organic') & (data['Annual_Rainfall'] > 600), 'Community_Name'].unique()
# Out:
# array(['Mountain Cultivators Club', 'Prairie Cultivators Club',
#        'Savannah Agri Society', 'Prairie Agricultural Association',
#        'Sunrise Growers Coalition', 'Valley Agricultural Association',
#        'Harvest Agricultural Association', 'Valley Farmers Union',
#        'Meadow Cultivators Club', 'Meadow Agricultural Association',
#        'Savannah Growers Coalition', 'Meadow Agri Society',
#        'River Cultivators Club', 'Mountain Agri Society',
#        'River Agricultural Association', 'Mountain Growers Coalition',
#        'Prairie Farmers Union', 'Green Farmers Union',
#        'Savannah Farmers Union', 'Green Farmers Group',
#        'Savannah Cultivators Club', 'Meadow Growers Coalition',
#        'Sunrise Farmers Group', 'Meadow Farmers Union',
#        'Sunrise Agricultural Association', 'Harvest Farmers Union',
#        'Harvest Cultivators Club', 'Prairie Agri Society',
#        'Green Agricultural Association', 'Sunrise Agri Society',
# ...

# %%
data[(data['Fertilizer_Type'] == 'Organic') & (data['Annual_Rainfall'] > 600)]['Irrigation'].unique()
# Out:
# array(['Sprinkler', 'Drip', nan], dtype=object)

# %% [markdown]
# Les communautés agricoles biologiques ayant une productivité supérieure à 600 utilisent principalement des technologies d’irrigation Sprinkler et Drip, avec certains cas où l’information n’est pas renseignée.
# Ces communautés démontrent qu’une agriculture biologique performante est possible grâce à des systèmes d’irrigation efficaces. Les technologies Sprinkler et Drip semblent jouer un rôle clé dans l’optimisation de la productivité tout en respectant les pratiques durables.
#
#
# Ces fermes peuvent servir de modèles ou de références pour la diffusion des bonnes pratiques durables. Promouvoir ces technologies auprès d’autres exploitations biologiques peut améliorer la productivité tout en renforçant la durabilité agricole.

# %% [markdown]
# ## Q6: Climate-Smart Agriculture Adoption
# **Business Question:** In high-rainfall regions (over 1000mm annually), which countries have farming communities that have invested in weather monitoring technology?
#
# **Context:** Weather station adoption in high-rainfall areas indicates sophisticated climate risk management practices.

# %%
data[(data['Annual_Rainfall'] > 1000) & (data['Weather_Station'] == 'Yes')]['Country'].unique()
# Out:
# array(['South Africa', 'Nigeria', 'Ghana', 'Tanzania', 'Kenya'],
#       dtype=object)

# %% [markdown]
# Les résultats montrent que l’Afrique du Sud, le Nigeria, le Ghana, la Tanzanie et le Kenya comptent des communautés situées dans des zones à fortes précipitations (plus de 1000 mm/an) ayant investi dans des stations météo.
# Ces investissements indiquent que ces communautés pratiquent une gestion avancée des risques climatiques, utilisant les données météo pour optimiser les semis, l’irrigation et la protection des cultures. Cela démontre une adoption proactive des technologies agricoles pour sécuriser la production.
#
# Ces pays représentent des marchés clés pour les solutions AgriTech liées au climat, et les communautés équipées de stations météo peuvent servir de modèles pour la diffusion de bonnes pratiques climato-intelligentes à d’autres exploitations.

# %% [markdown]
# ## Q7: Entry-Level Market Assessment
# **Business Question:** Among low-performing farming operations (annual yield under 200), which crop types are most prevalent and may need immediate intervention?
#
# **Context:** Low-yield operations represent potential clients for productivity improvement solutions.

# %%
data[data['Annual_Yield'] < 200 ]['Crop_Type'].unique()
# Out:
# array(['Barley', 'Sorghum', 'Rice', 'Wheat', 'Maize'], dtype=object)

# %% [markdown]
# Les exploitations à faible rendement (moins de 200) cultivent principalement l’orge (Barley), le sorgho (Sorghum), le riz (Rice), le blé (Wheat) et le maïs (Maize).
# Ces cultures de base sont essentielles pour la sécurité alimentaire, mais les faibles rendements indiquent un besoin urgent d’interventions technologiques et agronomiques. Des mesures comme l’amélioration des semences, la mécanisation, l’irrigation efficace et la formation agricole pourraient considérablement augmenter la productivité.
#
# Ces exploitations représentent des cibles prioritaires pour les programmes AgriTech et de renforcement des capacités. En intervenant sur ces cultures stratégiques, il est possible de maximiser l’impact économique et alimentaire tout en préparant ces fermes à l’adoption future de technologies plus avancées.

# %% [markdown]
# ## Q8: Digital Agriculture Penetration
# **Business Question:** What irrigation methods are most commonly used by digitally-enabled farming communities (those using Mobile Apps or SMS technology)?
#
# **Context:** Understanding technology adoption patterns helps design integrated digital agriculture solutions.

# %%
data[(data['Mobile_Tech'] == 'SMS') | (data['Mobile_Tech'] == 'Mobile Apps')]['Irrigation'].unique()
# Out:
# array(['Sprinkler', 'Drip', nan], dtype=object)

# %% [markdown]
# Les communautés agricoles connectées numériquement (utilisant des applications mobiles ou des SMS) privilégient principalement les méthodes d’irrigation Sprinkler et Drip, ou d'autres méthodes.
# L’usage de ces technologies montre que les agriculteurs numériquement connectés adoptent déjà des pratiques d’irrigation efficaces et modernes. Cela suggère un terrain favorable pour le déploiement de solutions AgriTech intégrées, combinant suivi de l’irrigation, alertes météo et conseils en temps réel via mobile.
#
# Ces communautés peuvent servir de modèles pilotes pour les solutions numériques intégrées, permettant d’optimiser l’irrigation, d’améliorer les rendements et de démontrer les avantages de la technologie aux autres exploitations.

# %% [markdown]
# ## Q9: Large-Scale Technology Investment Patterns
# **Business Question:** What is the average technology adoption level among large-scale farming operations (90+ acres), and how does it compare to smaller operations?
#
# **Context:** Large farms typically have higher investment capacity and can be early adopters of expensive technologies.

# %%
data[data['Tech_Adoption_Index'] >= 90]
# Out:
#                         Community_Name       Country Crop_Type  Farm_Size  \
# 17               Savannah Agri Society  South Africa   Sorghum      14.50
# 20           Savannah Cultivators Club         Kenya   Sorghum      46.27
# 36              Mountain Farmers Union  South Africa     Wheat       7.32
# 49                 Meadow Agri Society         Ghana   Sorghum      19.84
# 59            Meadow Growers Coalition       Nigeria     Maize       9.96
# ...                                ...           ...       ...        ...
# 1983               Golden Agri Society  South Africa   Sorghum      89.55
# 1991              Meadow Farmers Group         Kenya      Rice      84.23
# 1994            Green Cultivators Club       Nigeria     Wheat      26.81
# 1996            Mountain Farmers Group       Nigeria     Maize      50.99
# 1998  Sunrise Agricultural Association         Kenya     Wheat      87.01
#
#       Tech_Adoption_Index Drone_Usage  Mobile_Tech  Annual_Yield  \
# ...

# %%
data[data['Tech_Adoption_Index'] >= 90 ]['Tech_Adoption_Index'].mean()
# Out:
# np.float64(95.0377358490566)

# %%
data[data['Tech_Adoption_Index'] < 90]
# Out:
#                  Community_Name       Country Crop_Type  Farm_Size  \
# 0     Mountain Cultivators Club  South Africa    Barley      39.96
# 1      Prairie Cultivators Club  South Africa   Sorghum      77.62
# 2          Prairie Agri Society       Nigeria     Wheat      97.46
# 3         Harvest Farmers Union       Nigeria     Maize      27.84
# 4          Valley Farmers Group         Ghana   Sorghum      70.60
# ...                         ...           ...       ...        ...
# 1992       Valley Farmers Union      Tanzania    Barley      40.12
# 1993        Golden Agri Society         Kenya      Rice      90.02
# 1995       Harvest Agri Society         Kenya     Maize      39.93
# 1997   Prairie Cultivators Club         Ghana      Rice      89.37
# 1999     Savannah Farmers Group       Nigeria   Sorghum      57.86
#
#       Tech_Adoption_Index Drone_Usage  Mobile_Tech  Annual_Yield  \
# 0                      40         Yes          SMS        318.05
# ...

# %%
data[data['Tech_Adoption_Index'] < 90]['Tech_Adoption_Index'].mean()
# Out:
# np.float64(44.70973154362416)

# %% [markdown]
# Les résultats montrent que `les grandes exploitations (90+ acres)` présentent `un niveau moyen d’adoption technologique de 95,03`, tandis que `les exploitations plus petites affichent un niveau moyen de 44,70`.
# Cette différence significative illustre que les grandes fermes sont des précurseurs technologiques, capables d’investir dans des équipements et solutions avancés `(drones)`, alors que les petites exploitations adoptent la technologie plus lentement en raison de contraintes financières ou organisationnelles.
#
# Les grandes exploitations représentent un segment stratégique pour les partenariats et le déploiement rapide de nouvelles technologies, tandis que les petites fermes constituent un marché potentiel pour des solutions plus accessibles et graduelles, permettant de stimuler l’adoption progressive à plus large échelle.

# %% [markdown]
# ## Q10: Natural Farming Excellence
# **Business Question:** What percentage of farming communities achieve high productivity (over 500 annual yield) without using fertilizers, demonstrating natural farming excellence?
#
# **Context:** High-performing farms without fertilizer inputs represent efficient operations that could mentor others in sustainable practices.

# %%
import numpy as np

# %%
data[(data['Annual_Yield'] > 500) & ((data['Fertilizer_Type'] != 'Organic') & (data['Fertilizer_Type'] != 'Inorganic'))]
# Out:
#                  Community_Name       Country Crop_Type  Farm_Size  \
# 3         Harvest Farmers Union       Nigeria     Maize      27.84
# 4          Valley Farmers Group         Ghana   Sorghum      70.60
# 18        Mountain Agri Society       Nigeria     Wheat      62.62
# 19         Valley Farmers Group         Kenya     Maize      33.14
# 20    Savannah Cultivators Club         Kenya   Sorghum      46.27
# ...                         ...           ...       ...        ...
# 1983        Golden Agri Society  South Africa   Sorghum      89.55
# 1984       Meadow Farmers Union         Ghana     Wheat      84.12
# 1989       Harvest Agri Society         Kenya      Rice      55.40
# 1990       Golden Farmers Union       Nigeria     Wheat      19.07
# 1993        Golden Agri Society         Kenya      Rice      90.02
#
#       Tech_Adoption_Index Drone_Usage  Mobile_Tech  Annual_Yield  \
# 3                      55          No          SMS        668.23
# ...

# %%
community_no_fert = data[(data['Annual_Yield'] > 500) & ((data['Fertilizer_Type'] != 'Organic') & (data['Fertilizer_Type'] != 'Inorganic'))]['Community_Name'].unique()

# %%
community_no_fert
# Out:
# array(['Harvest Farmers Union', 'Valley Farmers Group',
#        'Mountain Agri Society', 'Savannah Cultivators Club',
#        'Golden Cultivators Club', 'Meadow Farmers Group',
#        'Mountain Agricultural Association',
#        'Valley Agricultural Association', 'Meadow Growers Coalition',
#        'Golden Agri Society', 'Harvest Farmers Group',
#        'Savannah Growers Coalition', 'Meadow Agri Society',
#        'Harvest Agricultural Association', 'River Agri Society',
#        'Green Cultivators Club', 'Mountain Growers Coalition',
#        'Prairie Agri Society', 'Mountain Farmers Group',
#        'Green Agricultural Association', 'Savannah Farmers Group',
#        'Harvest Agri Society', 'Sunrise Farmers Union',
#        'Meadow Farmers Union', 'Sunrise Farmers Group',
#        'Savannah Farmers Union', 'Golden Growers Coalition',
#        'River Agricultural Association', 'Valley Farmers Union',
#        'Golden Agricultural Association', 'Savannah Agri Society',
# ...

# %%
data.loc[(data['Annual_Yield'] > 500) & ((data['Fertilizer_Type'] != 'Organic') & (data['Fertilizer_Type'] != 'Inorganic')), 'Community_Name'].unique()
# Out:
# array(['Harvest Farmers Union', 'Valley Farmers Group',
#        'Mountain Agri Society', 'Savannah Cultivators Club',
#        'Golden Cultivators Club', 'Meadow Farmers Group',
#        'Mountain Agricultural Association',
#        'Valley Agricultural Association', 'Meadow Growers Coalition',
#        'Golden Agri Society', 'Harvest Farmers Group',
#        'Savannah Growers Coalition', 'Meadow Agri Society',
#        'Harvest Agricultural Association', 'River Agri Society',
#        'Green Cultivators Club', 'Mountain Growers Coalition',
#        'Prairie Agri Society', 'Mountain Farmers Group',
#        'Green Agricultural Association', 'Savannah Farmers Group',
#        'Harvest Agri Society', 'Sunrise Farmers Union',
#        'Meadow Farmers Union', 'Sunrise Farmers Group',
#        'Savannah Farmers Union', 'Golden Growers Coalition',
#        'River Agricultural Association', 'Valley Farmers Union',
#        'Golden Agricultural Association', 'Savannah Agri Society',
# ...

# %%
tab_community_no_fert = pd.Series(community_no_fert)

# %%
count_community_no_fert = tab_community_no_fert.count()
count_community_no_fert
# Out:
# np.int64(60)

# %%
total_com = data['Community_Name'].count()

# %%
percent_community_no_fert = (count_community_no_fert/total_com)*100
percent_community_no_fert
# Out:
# np.float64(3.0)

# %% [markdown]
# Les résultats montrent que seulement `3,0 % des communautés agricoles` atteignent une productivité supérieure à 500 sans utiliser d’engrais.
# Ce faible pourcentage indique que la production élevée sans intrants chimiques est rare, mais ces exploitations constituent des modèles remarquables d’efficacité durable. Elles démontrent que des pratiques agricoles naturelles bien maîtrisées peuvent générer des rendements compétitifs.
#
# Ces communautés représentent des références pour la promotion de l’agriculture durable et les bonnes pratiques naturelles. Les valoriser et documenter leurs méthodes peut inspirer et guider d’autres exploitations vers des solutions à la fois productives et respectueuses de l’environnement.
